# %% [markdown]
# ## Preprocessing

# %%
# Import our dependencies
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import pandas as pd
import tensorflow as tf
import matplotlib.pyplot as plt

#  Import and read the charity_data.csv.
import pandas as pd 
application_df = pd.read_csv("https://static.bc-edx.com/data/dl-1-2/m21/lms/starter/charity_data.csv")
application_df.head()
# Out:
#         EIN                                      NAME APPLICATION_TYPE
# 0  10520599              BLUE KNIGHTS MOTORCYCLE CLUB              T10  \
# 1  10531628    AMERICAN CHESAPEAKE CLUB CHARITABLE TR               T3
# 2  10547893        ST CLOUD PROFESSIONAL FIREFIGHTERS               T5
# 3  10553066            SOUTHSIDE ATHLETIC ASSOCIATION               T3
# 4  10556103  GENETIC RESEARCH INSTITUTE OF THE DESERT               T3
#
#         AFFILIATION CLASSIFICATION      USE_CASE  ORGANIZATION  STATUS
# 0       Independent          C1000    ProductDev   Association       1  \
# 1       Independent          C2000  Preservation  Co-operative       1
# 2  CompanySponsored          C3000    ProductDev   Association       1
# 3  CompanySponsored          C2000  Preservation         Trust       1
# 4       Independent          C1000     Heathcare         Trust       1
#
#       INCOME_AMT SPECIAL_CONSIDERATIONS  ASK_AMT  IS_SUCCESSFUL
# 0              0                      N     5000              1
# 1         1-9999                      N   108590              1
# 2              0                      N     5000              0
# 3    10000-24999                      N     6692              1
# 4  100000-499999                      N   142590              1

# %%
# Drop the non-beneficial ID columns, 'EIN' and 'NAME'.
application_df = application_df.drop(["EIN", "NAME"], axis=1)
application_df.head()
# Out:
#   APPLICATION_TYPE       AFFILIATION CLASSIFICATION      USE_CASE
# 0              T10       Independent          C1000    ProductDev  \
# 1               T3       Independent          C2000  Preservation
# 2               T5  CompanySponsored          C3000    ProductDev
# 3               T3  CompanySponsored          C2000  Preservation
# 4               T3       Independent          C1000     Heathcare
#
#    ORGANIZATION  STATUS     INCOME_AMT SPECIAL_CONSIDERATIONS  ASK_AMT
# 0   Association       1              0                      N     5000  \
# 1  Co-operative       1         1-9999                      N   108590
# 2   Association       1              0                      N     5000
# 3         Trust       1    10000-24999                      N     6692
# 4         Trust       1  100000-499999                      N   142590
#
#    IS_SUCCESSFUL
# 0              1
# 1              1
# 2              0
# 3              1
# 4              1

# %% [markdown]
# TARGET VARIABLE: IS_SUCCESSFUL
#
# FEATURES: all other columns

# %%
# Determine the number of unique values in each column.
application_df.nunique()
# Out:
# APPLICATION_TYPE            17
# AFFILIATION                  6
# CLASSIFICATION              71
# USE_CASE                     5
# ORGANIZATION                 4
# STATUS                       2
# INCOME_AMT                   9
# SPECIAL_CONSIDERATIONS       2
# ASK_AMT                   8747
# IS_SUCCESSFUL                2
# dtype: int64

# %%
# Look at APPLICATION_TYPE value counts for binning
app_count = application_df["APPLICATION_TYPE"].value_counts()
app_count
# Out:
# APPLICATION_TYPE
# T3     27037
# T4      1542
# T6      1216
# T5      1173
# T19     1065
# T8       737
# T7       725
# T10      528
# T9       156
# T13       66
# T12       27
# T2        16
# T25        3
# T14        3
# T29        2
# T15        2
# T17        1
# Name: count, dtype: int64

# %%
# Choose a cutoff value and create a list of application types to be replaced
# use the variable name `application_types_to_replace`
application_types_to_replace = list(app_count[app_count < 500].index)

# Replace in dataframe
for app in application_types_to_replace:
    application_df['APPLICATION_TYPE'] = application_df['APPLICATION_TYPE'].replace(app,"Other")

# Check to make sure binning was successful
application_df['APPLICATION_TYPE'].value_counts()
# Out:
# APPLICATION_TYPE
# T3       27037
# T4        1542
# T6        1216
# T5        1173
# T19       1065
# T8         737
# T7         725
# T10        528
# Other      276
# Name: count, dtype: int64

# %%
# Look at CLASSIFICATION value counts for binning
class_count = application_df["CLASSIFICATION"].value_counts()
class_count
# Out:
# CLASSIFICATION
# C1000    17326
# C2000     6074
# C1200     4837
# C3000     1918
# C2100     1883
#          ...
# C4120        1
# C8210        1
# C2561        1
# C4500        1
# C2150        1
# Name: count, Length: 71, dtype: int64

# %%
# You may find it helpful to look at CLASSIFICATION value counts >1
class_count[class_count > 1]
# Out:
# CLASSIFICATION
# C1000    17326
# C2000     6074
# C1200     4837
# C3000     1918
# C2100     1883
# C7000      777
# C1700      287
# C4000      194
# C5000      116
# C1270      114
# C2700      104
# C2800       95
# C7100       75
# C1300       58
# C1280       50
# C1230       36
# C1400       34
# C7200       32
# C2300       32
# C1240       30
# C8000       20
# C7120       18
# C1500       16
# C1800       15
# C6000       15
# C1250       14
# C8200       11
# C1238       10
# C1278       10
# C1235        9
# C1237        9
# C7210        7
# C2400        6
# C1720        6
# C4100        6
# C1257        5
# C1600        5
# C1260        3
# C2710        3
# C0           3
# C3200        2
# C1234        2
# C1246        2
# C1267        2
# C1256        2
# Name: count, dtype: int64

# %%
# Choose a cutoff value and create a list of classifications to be replaced
# use the variable name `classifications_to_replace`
classifications_to_replace = list(class_count[class_count < 1000].index)

# Replace in dataframe
for cls in classifications_to_replace:
    application_df['CLASSIFICATION'] = application_df['CLASSIFICATION'].replace(cls,"Other")
    
# Check to make sure binning was successful
application_df['CLASSIFICATION'].value_counts()
# Out:
# CLASSIFICATION
# C1000    17326
# C2000     6074
# C1200     4837
# Other     2261
# C3000     1918
# C2100     1883
# Name: count, dtype: int64

# %%
# Convert categorical data to numeric with `pd.get_dummies`
app_dummies = application_df = pd.get_dummies(application_df)
app_dummies.head()
# Out:
#    STATUS  ASK_AMT  IS_SUCCESSFUL  APPLICATION_TYPE_Other
# 0       1     5000              1                   False  \
# 1       1   108590              1                   False
# 2       1     5000              0                   False
# 3       1     6692              1                   False
# 4       1   142590              1                   False
#
#    APPLICATION_TYPE_T10  APPLICATION_TYPE_T19  APPLICATION_TYPE_T3
# 0                  True                 False                False  \
# 1                 False                 False                 True
# 2                 False                 False                False
# 3                 False                 False                 True
# 4                 False                 False                 True
#
#    APPLICATION_TYPE_T4  APPLICATION_TYPE_T5  APPLICATION_TYPE_T6  ...
# 0                False                False                False  ...  \
# 1                False                False                False  ...
# 2                False                 True                False  ...
# 3                False                False                False  ...
# 4                False                False                False  ...
#
#    INCOME_AMT_1-9999  INCOME_AMT_10000-24999  INCOME_AMT_100000-499999
# 0              False                   False                     False  \
# 1               True                   False                     False
# 2              False                   False                     False
# 3              False                    True                     False
# 4              False                   False                      True
#
#    INCOME_AMT_10M-50M  INCOME_AMT_1M-5M  INCOME_AMT_25000-99999
# 0               False             False                   False  \
# 1               False             False                   False
# 2               False             False                   False
# 3               False             False                   False
# 4               False             False                   False
#
#    INCOME_AMT_50M+  INCOME_AMT_5M-10M  SPECIAL_CONSIDERATIONS_N
# 0            False              False                      True  \
# 1            False              False                      True
# 2            False              False                      True
# 3            False              False                      True
# 4            False              False                      True
#
#    SPECIAL_CONSIDERATIONS_Y
# 0                     False
# 1                     False
# 2                     False
# 3                     False
# 4                     False
#
# [5 rows x 44 columns]

# %%
# Split our preprocessed data into our features and target arrays
X = app_dummies.drop(["IS_SUCCESSFUL"], axis=1).values
y = app_dummies["IS_SUCCESSFUL"].values

# Split the preprocessed data into a training and testing dataset
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=78)

# %%
# Create a StandardScaler instances
scaler = StandardScaler()

# Fit the StandardScaler
X_scaler = scaler.fit(X_train)

# Scale the data
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %% [markdown]
# ## Compile, Train and Evaluate the Model

# %%
# Define the model - deep neural net, i.e., the number of input features and hidden nodes for each layer.
inputs = len(X_test_scaled[0])
layer1 = 6
layer2 = 15

nn = tf.keras.models.Sequential()

# First hidden layer
nn.add(tf.keras.layers.Dense(units=layer1, input_dim=inputs, activation="relu"))

# Second hidden layer
nn.add(tf.keras.layers.Dense(units=layer2, activation="relu"))

# Output layer
nn.add(tf.keras.layers.Dense(units=1, activation="sigmoid"))

# Check the structure of the model
nn.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 6)                 264
#
#  dense_1 (Dense)             (None, 15)                105
#
#  dense_2 (Dense)             (None, 1)                 16
#
# =================================================================
# Total params: 385 (1.50 KB)
# Trainable params: 385 (1.50 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# Compile the model
nn.compile(loss="binary_crossentropy", optimizer="adam", metrics=["accuracy"])

# %%
# Train the model
fit_model = nn.fit(X_train_scaled, y_train, epochs=150)
# Out:
# Epoch 1/150
# 804/804 [==============================] - 1s 854us/step - loss: 0.6134 - accuracy: 0.7028
# Epoch 2/150
# 804/804 [==============================] - 1s 805us/step - loss: 0.5736 - accuracy: 0.7242
# Epoch 3/150
# 804/804 [==============================] - 1s 843us/step - loss: 0.5646 - accuracy: 0.7260
# Epoch 4/150
# 804/804 [==============================] - 1s 923us/step - loss: 0.5602 - accuracy: 0.7275
# Epoch 5/150
# 804/804 [==============================] - 1s 843us/step - loss: 0.5575 - accuracy: 0.7282
# Epoch 6/150
# 804/804 [==============================] - 1s 850us/step - loss: 0.5561 - accuracy: 0.7296
# Epoch 7/150
# 804/804 [==============================] - 1s 933us/step - loss: 0.5547 - accuracy: 0.7302
# Epoch 8/150
# 804/804 [==============================] - 1s 898us/step - loss: 0.5543 - accuracy: 0.7303
# Epoch 9/150
# 804/804 [==============================] - 1s 939us/step - loss: 0.5533 - accuracy: 0.7313
# Epoch 10/150
# 804/804 [==============================] - 1s 843us/step - loss: 0.5529 - accuracy: 0.7303
# Epoch 11/150
# 804/804 [==============================] - 1s 850us/step - loss: 0.5527 - accuracy: 0.7304
# Epoch 12/150
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5521 - accuracy: 0.7308
# Epoch 13/150
# 804/804 [==============================] - 1s 884us/step - loss: 0.5518 - accuracy: 0.7305
# Epoch 14/150
# 804/804 [==============================] - 1s 856us/step - loss: 0.5516 - accuracy: 0.7317
# Epoch 15/150
# 804/804 [==============================] - 1s 908us/step - loss: 0.5514 - accuracy: 0.7306
# Epoch 16/150
# 804/804 [==============================] - 1s 922us/step - loss: 0.5511 - accuracy: 0.7318
# Epoch 17/150
# 804/804 [==============================] - 1s 902us/step - loss: 0.5512 - accuracy: 0.7314
# Epoch 18/150
# 804/804 [==============================] - 1s 861us/step - loss: 0.5507 - accuracy: 0.7316
# Epoch 19/150
# 804/804 [==============================] - 1s 841us/step - loss: 0.5507 - accuracy: 0.7315
# Epoch 20/150
# 804/804 [==============================] - 1s 909us/step - loss: 0.5505 - accuracy: 0.7309
# Epoch 21/150
# 804/804 [==============================] - 1s 883us/step - loss: 0.5504 - accuracy: 0.7318
# Epoch 22/150
# 804/804 [==============================] - 1s 844us/step - loss: 0.5499 - accuracy: 0.7322
# Epoch 23/150
# 804/804 [==============================] - 1s 902us/step - loss: 0.5500 - accuracy: 0.7318
# Epoch 24/150
# 804/804 [==============================] - 1s 831us/step - loss: 0.5498 - accuracy: 0.7323
# Epoch 25/150
# 804/804 [==============================] - 1s 829us/step - loss: 0.5497 - accuracy: 0.7324
# Epoch 26/150
# 804/804 [==============================] - 1s 880us/step - loss: 0.5496 - accuracy: 0.7324
# Epoch 27/150
# 804/804 [==============================] - 1s 884us/step - loss: 0.5492 - accuracy: 0.7329
# Epoch 28/150
# 804/804 [==============================] - 1s 860us/step - loss: 0.5490 - accuracy: 0.7331
# Epoch 29/150
# 804/804 [==============================] - 1s 841us/step - loss: 0.5488 - accuracy: 0.7331
# Epoch 30/150
# 804/804 [==============================] - 1s 870us/step - loss: 0.5489 - accuracy: 0.7323
# Epoch 31/150
# 804/804 [==============================] - 1s 861us/step - loss: 0.5489 - accuracy: 0.7323
# Epoch 32/150
# 804/804 [==============================] - 1s 848us/step - loss: 0.5487 - accuracy: 0.7337
# Epoch 33/150
# 804/804 [==============================] - 1s 830us/step - loss: 0.5485 - accuracy: 0.7327
# Epoch 34/150
# 804/804 [==============================] - 1s 833us/step - loss: 0.5486 - accuracy: 0.7333
# Epoch 35/150
# 804/804 [==============================] - 1s 814us/step - loss: 0.5486 - accuracy: 0.7324
# Epoch 36/150
# 804/804 [==============================] - 1s 886us/step - loss: 0.5485 - accuracy: 0.7323
# Epoch 37/150
# 804/804 [==============================] - 1s 876us/step - loss: 0.5481 - accuracy: 0.7328
# Epoch 38/150
# 804/804 [==============================] - 1s 909us/step - loss: 0.5480 - accuracy: 0.7328
# Epoch 39/150
# 804/804 [==============================] - 1s 888us/step - loss: 0.5478 - accuracy: 0.7328
# Epoch 40/150
# 804/804 [==============================] - 1s 953us/step - loss: 0.5479 - accuracy: 0.7339
# Epoch 41/150
# 804/804 [==============================] - 1s 988us/step - loss: 0.5477 - accuracy: 0.7338
# Epoch 42/150
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5476 - accuracy: 0.7336
# Epoch 43/150
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5476 - accuracy: 0.7343
# Epoch 44/150
# 804/804 [==============================] - 1s 951us/step - loss: 0.5477 - accuracy: 0.7337
# Epoch 45/150
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5477 - accuracy: 0.7335
# Epoch 46/150
# 804/804 [==============================] - 1s 963us/step - loss: 0.5474 - accuracy: 0.7328
# Epoch 47/150
# 804/804 [==============================] - 1s 992us/step - loss: 0.5474 - accuracy: 0.7334
# Epoch 48/150
# 804/804 [==============================] - 1s 986us/step - loss: 0.5473 - accuracy: 0.7348
# Epoch 49/150
# 804/804 [==============================] - 1s 941us/step - loss: 0.5471 - accuracy: 0.7343
# Epoch 50/150
# 804/804 [==============================] - 1s 947us/step - loss: 0.5475 - accuracy: 0.7337
# Epoch 51/150
# 804/804 [==============================] - 1s 935us/step - loss: 0.5474 - accuracy: 0.7334
# Epoch 52/150
# 804/804 [==============================] - 1s 994us/step - loss: 0.5473 - accuracy: 0.7342
# Epoch 53/150
# 804/804 [==============================] - 1s 930us/step - loss: 0.5474 - accuracy: 0.7342
# Epoch 54/150
# 804/804 [==============================] - 1s 976us/step - loss: 0.5471 - accuracy: 0.7343
# Epoch 55/150
# 804/804 [==============================] - 1s 990us/step - loss: 0.5472 - accuracy: 0.7340
# Epoch 56/150
# 804/804 [==============================] - 1s 963us/step - loss: 0.5474 - accuracy: 0.7339
# Epoch 57/150
# 804/804 [==============================] - 1s 921us/step - loss: 0.5471 - accuracy: 0.7337
# Epoch 58/150
# 804/804 [==============================] - 1s 937us/step - loss: 0.5469 - accuracy: 0.7333
# Epoch 59/150
# 804/804 [==============================] - 1s 996us/step - loss: 0.5469 - accuracy: 0.7345
# Epoch 60/150
# 804/804 [==============================] - 1s 947us/step - loss: 0.5471 - accuracy: 0.7341
# Epoch 61/150
# 804/804 [==============================] - 1s 988us/step - loss: 0.5472 - accuracy: 0.7345
# Epoch 62/150
# 804/804 [==============================] - 1s 977us/step - loss: 0.5471 - accuracy: 0.7345
# Epoch 63/150
# 804/804 [==============================] - 1s 943us/step - loss: 0.5468 - accuracy: 0.7350
# Epoch 64/150
# 804/804 [==============================] - 1s 939us/step - loss: 0.5467 - accuracy: 0.7343
# Epoch 65/150
# 804/804 [==============================] - 1s 912us/step - loss: 0.5468 - accuracy: 0.7343
# Epoch 66/150
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5471 - accuracy: 0.7338
# Epoch 67/150
# 804/804 [==============================] - 1s 922us/step - loss: 0.5466 - accuracy: 0.7341
# Epoch 68/150
# 804/804 [==============================] - 1s 924us/step - loss: 0.5470 - accuracy: 0.7341
# Epoch 69/150
# 804/804 [==============================] - 1s 995us/step - loss: 0.5467 - accuracy: 0.7343
# Epoch 70/150
# 804/804 [==============================] - 1s 965us/step - loss: 0.5468 - accuracy: 0.7341
# Epoch 71/150
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5470 - accuracy: 0.7346
# Epoch 72/150
# 804/804 [==============================] - 1s 987us/step - loss: 0.5469 - accuracy: 0.7350
# Epoch 73/150
# 804/804 [==============================] - 1s 913us/step - loss: 0.5465 - accuracy: 0.7336
# Epoch 74/150
# 804/804 [==============================] - 1s 939us/step - loss: 0.5467 - accuracy: 0.7346
# Epoch 75/150
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5467 - accuracy: 0.7339
# Epoch 76/150
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5469 - accuracy: 0.7344
# Epoch 77/150
# 804/804 [==============================] - 1s 924us/step - loss: 0.5466 - accuracy: 0.7348
# Epoch 78/150
# 804/804 [==============================] - 1s 942us/step - loss: 0.5468 - accuracy: 0.7332
# Epoch 79/150
# 804/804 [==============================] - 1s 836us/step - loss: 0.5462 - accuracy: 0.7352
# Epoch 80/150
# 804/804 [==============================] - 1s 899us/step - loss: 0.5462 - accuracy: 0.7339
# Epoch 81/150
# 804/804 [==============================] - 1s 943us/step - loss: 0.5466 - accuracy: 0.7345
# Epoch 82/150
# 804/804 [==============================] - 1s 903us/step - loss: 0.5466 - accuracy: 0.7336
# Epoch 83/150
# 804/804 [==============================] - 1s 889us/step - loss: 0.5465 - accuracy: 0.7353
# Epoch 84/150
# 804/804 [==============================] - 1s 888us/step - loss: 0.5462 - accuracy: 0.7338
# Epoch 85/150
# 804/804 [==============================] - 1s 894us/step - loss: 0.5462 - accuracy: 0.7342
# Epoch 86/150
# 804/804 [==============================] - 1s 897us/step - loss: 0.5463 - accuracy: 0.7353
# Epoch 87/150
# 804/804 [==============================] - 1s 892us/step - loss: 0.5460 - accuracy: 0.7341
# Epoch 88/150
# 804/804 [==============================] - 1s 974us/step - loss: 0.5462 - accuracy: 0.7348
# Epoch 89/150
# 804/804 [==============================] - 1s 1000us/step - loss: 0.5465 - accuracy: 0.7346
# Epoch 90/150
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5462 - accuracy: 0.7342
# Epoch 91/150
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5463 - accuracy: 0.7336
# Epoch 92/150
# 804/804 [==============================] - 1s 963us/step - loss: 0.5461 - accuracy: 0.7350
# Epoch 93/150
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5461 - accuracy: 0.7347
# Epoch 94/150
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5462 - accuracy: 0.7355
# Epoch 95/150
# 804/804 [==============================] - 1s 943us/step - loss: 0.5459 - accuracy: 0.7342
# Epoch 96/150
# 804/804 [==============================] - 1s 998us/step - loss: 0.5463 - accuracy: 0.7337
# Epoch 97/150
# 804/804 [==============================] - 1s 919us/step - loss: 0.5464 - accuracy: 0.7339
# Epoch 98/150
# 804/804 [==============================] - 1s 964us/step - loss: 0.5466 - accuracy: 0.7344
# Epoch 99/150
# 804/804 [==============================] - 1s 952us/step - loss: 0.5459 - accuracy: 0.7348
# Epoch 100/150
# 804/804 [==============================] - 1s 922us/step - loss: 0.5463 - accuracy: 0.7348
# Epoch 101/150
# 804/804 [==============================] - 1s 940us/step - loss: 0.5459 - accuracy: 0.7336
# Epoch 102/150
# 804/804 [==============================] - 1s 967us/step - loss: 0.5458 - accuracy: 0.7343
# Epoch 103/150
# 804/804 [==============================] - 1s 991us/step - loss: 0.5460 - accuracy: 0.7354
# Epoch 104/150
# 804/804 [==============================] - 1s 940us/step - loss: 0.5457 - accuracy: 0.7340
# Epoch 105/150
# 804/804 [==============================] - 1s 967us/step - loss: 0.5461 - accuracy: 0.7340
# Epoch 106/150
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5459 - accuracy: 0.7349
# Epoch 107/150
# 804/804 [==============================] - 1s 901us/step - loss: 0.5459 - accuracy: 0.7350
# Epoch 108/150
# 804/804 [==============================] - 1s 924us/step - loss: 0.5459 - accuracy: 0.7346
# Epoch 109/150
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5456 - accuracy: 0.7338
# Epoch 110/150
# 804/804 [==============================] - 1s 910us/step - loss: 0.5458 - accuracy: 0.7352
# Epoch 111/150
# 804/804 [==============================] - 1s 954us/step - loss: 0.5463 - accuracy: 0.7338
# Epoch 112/150
# 804/804 [==============================] - 1s 995us/step - loss: 0.5459 - accuracy: 0.7346
# Epoch 113/150
# 804/804 [==============================] - 1s 931us/step - loss: 0.5460 - accuracy: 0.7348
# Epoch 114/150
# 804/804 [==============================] - 1s 965us/step - loss: 0.5458 - accuracy: 0.7345
# Epoch 115/150
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5458 - accuracy: 0.7356
# Epoch 116/150
# 804/804 [==============================] - 1s 976us/step - loss: 0.5458 - accuracy: 0.7356
# Epoch 117/150
# 804/804 [==============================] - 1s 925us/step - loss: 0.5456 - accuracy: 0.7353
# Epoch 118/150
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5457 - accuracy: 0.7353
# Epoch 119/150
# 804/804 [==============================] - 1s 964us/step - loss: 0.5464 - accuracy: 0.7346
# Epoch 120/150
# 804/804 [==============================] - 1s 882us/step - loss: 0.5457 - accuracy: 0.7351
# Epoch 121/150
# 804/804 [==============================] - 1s 983us/step - loss: 0.5460 - accuracy: 0.7355
# Epoch 122/150
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5459 - accuracy: 0.7353
# Epoch 123/150
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5455 - accuracy: 0.7343
# Epoch 124/150
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5458 - accuracy: 0.7337
# Epoch 125/150
# 804/804 [==============================] - 1s 941us/step - loss: 0.5458 - accuracy: 0.7346
# Epoch 126/150
# 804/804 [==============================] - 1s 989us/step - loss: 0.5457 - accuracy: 0.7349
# Epoch 127/150
# 804/804 [==============================] - 1s 961us/step - loss: 0.5457 - accuracy: 0.7347
# Epoch 128/150
# 804/804 [==============================] - 1s 904us/step - loss: 0.5456 - accuracy: 0.7348
# Epoch 129/150
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5455 - accuracy: 0.7346
# Epoch 130/150
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5455 - accuracy: 0.7356
# Epoch 131/150
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5456 - accuracy: 0.7338
# Epoch 132/150
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5454 - accuracy: 0.7345
# Epoch 133/150
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5459 - accuracy: 0.7336
# Epoch 134/150
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5457 - accuracy: 0.7349
# Epoch 135/150
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5454 - accuracy: 0.7359
# Epoch 136/150
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5455 - accuracy: 0.7355
# Epoch 137/150
# 804/804 [==============================] - 1s 932us/step - loss: 0.5458 - accuracy: 0.7348
# Epoch 138/150
# 804/804 [==============================] - 1s 911us/step - loss: 0.5459 - accuracy: 0.7343
# Epoch 139/150
# 804/804 [==============================] - 1s 997us/step - loss: 0.5457 - accuracy: 0.7349
# Epoch 140/150
# 804/804 [==============================] - 1s 934us/step - loss: 0.5459 - accuracy: 0.7346
# Epoch 141/150
# 804/804 [==============================] - 1s 936us/step - loss: 0.5455 - accuracy: 0.7354
# Epoch 142/150
# 804/804 [==============================] - 1s 993us/step - loss: 0.5455 - accuracy: 0.7337
# Epoch 143/150
# 804/804 [==============================] - 1s 920us/step - loss: 0.5455 - accuracy: 0.7352
# Epoch 144/150
# 804/804 [==============================] - 1s 982us/step - loss: 0.5456 - accuracy: 0.7351
# Epoch 145/150
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5456 - accuracy: 0.7350
# Epoch 146/150
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5456 - accuracy: 0.7352
# Epoch 147/150
# 804/804 [==============================] - 1s 976us/step - loss: 0.5457 - accuracy: 0.7350
# Epoch 148/150
# 804/804 [==============================] - 1s 923us/step - loss: 0.5454 - accuracy: 0.7344
# Epoch 149/150
# 804/804 [==============================] - 1s 970us/step - loss: 0.5455 - accuracy: 0.7358
# Epoch 150/150
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5455 - accuracy: 0.7355

# %%
# Evaluate the model using the test data
model_loss, model_accuracy = nn.evaluate(X_test_scaled,y_test,verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 268/268 - 0s - loss: 0.5555 - accuracy: 0.7261 - 417ms/epoch - 2ms/step
# Loss: 0.5555250644683838, Accuracy: 0.726064145565033

# %%
loss_df = pd.DataFrame(fit_model.history, index=range(1,len(fit_model.history["loss"])+1))
Attempt1 = loss_df.plot(y="accuracy")

# %%
# Save Plot to images folder
plt.savefig("Images/Attempt1.png")

# %%
# Export our model to HDF5 file
nn.save("h5_Files/AlphabetSoupCharity.h5")
# Out:
# c:\Users\Rstev\anaconda3\lib\site-packages\keras\src\engine\training.py:3000: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
