# %%
# Import our dependencies
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import pandas as pd
import tensorflow as tf
import matplotlib.pyplot as plt
import keras_tuner as kt

#  Import and read the charity_data.csv.
import pandas as pd 
application_df = pd.read_csv("https://static.bc-edx.com/data/dl-1-2/m21/lms/starter/charity_data.csv")
application_df.head()
# Out:
#         EIN                                      NAME APPLICATION_TYPE
# 0  10520599              BLUE KNIGHTS MOTORCYCLE CLUB              T10  \
# 1  10531628    AMERICAN CHESAPEAKE CLUB CHARITABLE TR               T3
# 2  10547893        ST CLOUD PROFESSIONAL FIREFIGHTERS               T5
# 3  10553066            SOUTHSIDE ATHLETIC ASSOCIATION               T3
# 4  10556103  GENETIC RESEARCH INSTITUTE OF THE DESERT               T3
#
#         AFFILIATION CLASSIFICATION      USE_CASE  ORGANIZATION  STATUS
# 0       Independent          C1000    ProductDev   Association       1  \
# 1       Independent          C2000  Preservation  Co-operative       1
# 2  CompanySponsored          C3000    ProductDev   Association       1
# 3  CompanySponsored          C2000  Preservation         Trust       1
# 4       Independent          C1000     Heathcare         Trust       1
#
#       INCOME_AMT SPECIAL_CONSIDERATIONS  ASK_AMT  IS_SUCCESSFUL
# 0              0                      N     5000              1
# 1         1-9999                      N   108590              1
# 2              0                      N     5000              0
# 3    10000-24999                      N     6692              1
# 4  100000-499999                      N   142590              1

# %%
# Drop the non-beneficial ID columns, 'EIN' and 'NAME'.
application_df = application_df.drop(["EIN", "NAME"], axis=1)
application_df.head()
# Out:
#   APPLICATION_TYPE       AFFILIATION CLASSIFICATION      USE_CASE
# 0              T10       Independent          C1000    ProductDev  \
# 1               T3       Independent          C2000  Preservation
# 2               T5  CompanySponsored          C3000    ProductDev
# 3               T3  CompanySponsored          C2000  Preservation
# 4               T3       Independent          C1000     Heathcare
#
#    ORGANIZATION  STATUS     INCOME_AMT SPECIAL_CONSIDERATIONS  ASK_AMT
# 0   Association       1              0                      N     5000  \
# 1  Co-operative       1         1-9999                      N   108590
# 2   Association       1              0                      N     5000
# 3         Trust       1    10000-24999                      N     6692
# 4         Trust       1  100000-499999                      N   142590
#
#    IS_SUCCESSFUL
# 0              1
# 1              1
# 2              0
# 3              1
# 4              1

# %%
# Determine the number of unique values in each column.
application_df.nunique()
# Out:
# APPLICATION_TYPE            17
# AFFILIATION                  6
# CLASSIFICATION              71
# USE_CASE                     5
# ORGANIZATION                 4
# STATUS                       2
# INCOME_AMT                   9
# SPECIAL_CONSIDERATIONS       2
# ASK_AMT                   8747
# IS_SUCCESSFUL                2
# dtype: int64

# %%
# Look at APPLICATION_TYPE value counts for binning
app_count = application_df["APPLICATION_TYPE"].value_counts()
app_count
# Out:
# APPLICATION_TYPE
# T3     27037
# T4      1542
# T6      1216
# T5      1173
# T19     1065
# T8       737
# T7       725
# T10      528
# T9       156
# T13       66
# T12       27
# T2        16
# T25        3
# T14        3
# T29        2
# T15        2
# T17        1
# Name: count, dtype: int64

# %%
# Choose a cutoff value and create a list of application types to be replaced
# use the variable name `application_types_to_replace`
application_types_to_replace = list(app_count[app_count < 500].index)

# Replace in dataframe
for app in application_types_to_replace:
    application_df['APPLICATION_TYPE'] = application_df['APPLICATION_TYPE'].replace(app,"Other")

# Check to make sure binning was successful
application_df['APPLICATION_TYPE'].value_counts()
# Out:
# APPLICATION_TYPE
# T3       27037
# T4        1542
# T6        1216
# T5        1173
# T19       1065
# T8         737
# T7         725
# T10        528
# Other      276
# Name: count, dtype: int64

# %%
# Look at CLASSIFICATION value counts for binning
class_count = application_df["CLASSIFICATION"].value_counts()
class_count
# Out:
# CLASSIFICATION
# C1000    17326
# C2000     6074
# C1200     4837
# C3000     1918
# C2100     1883
#          ...
# C4120        1
# C8210        1
# C2561        1
# C4500        1
# C2150        1
# Name: count, Length: 71, dtype: int64

# %%
# You may find it helpful to look at CLASSIFICATION value counts >1
class_count[class_count > 1]
# Out:
# CLASSIFICATION
# C1000    17326
# C2000     6074
# C1200     4837
# C3000     1918
# C2100     1883
# C7000      777
# C1700      287
# C4000      194
# C5000      116
# C1270      114
# C2700      104
# C2800       95
# C7100       75
# C1300       58
# C1280       50
# C1230       36
# C1400       34
# C7200       32
# C2300       32
# C1240       30
# C8000       20
# C7120       18
# C1500       16
# C1800       15
# C6000       15
# C1250       14
# C8200       11
# C1238       10
# C1278       10
# C1235        9
# C1237        9
# C7210        7
# C2400        6
# C1720        6
# C4100        6
# C1257        5
# C1600        5
# C1260        3
# C2710        3
# C0           3
# C3200        2
# C1234        2
# C1246        2
# C1267        2
# C1256        2
# Name: count, dtype: int64

# %%
# Choose a cutoff value and create a list of classifications to be replaced
# use the variable name `classifications_to_replace`
classifications_to_replace = list(class_count[class_count < 1000].index)

# Replace in dataframe
for cls in classifications_to_replace:
    application_df['CLASSIFICATION'] = application_df['CLASSIFICATION'].replace(cls,"Other")
    
# Check to make sure binning was successful
application_df['CLASSIFICATION'].value_counts()
# Out:
# CLASSIFICATION
# C1000    17326
# C2000     6074
# C1200     4837
# Other     2261
# C3000     1918
# C2100     1883
# Name: count, dtype: int64

# %%
# Convert categorical data to numeric with `pd.get_dummies`
app_dummies = application_df = pd.get_dummies(application_df)
app_dummies.head()
# Out:
#    STATUS  ASK_AMT  IS_SUCCESSFUL  APPLICATION_TYPE_Other
# 0       1     5000              1                   False  \
# 1       1   108590              1                   False
# 2       1     5000              0                   False
# 3       1     6692              1                   False
# 4       1   142590              1                   False
#
#    APPLICATION_TYPE_T10  APPLICATION_TYPE_T19  APPLICATION_TYPE_T3
# 0                  True                 False                False  \
# 1                 False                 False                 True
# 2                 False                 False                False
# 3                 False                 False                 True
# 4                 False                 False                 True
#
#    APPLICATION_TYPE_T4  APPLICATION_TYPE_T5  APPLICATION_TYPE_T6  ...
# 0                False                False                False  ...  \
# 1                False                False                False  ...
# 2                False                 True                False  ...
# 3                False                False                False  ...
# 4                False                False                False  ...
#
#    INCOME_AMT_1-9999  INCOME_AMT_10000-24999  INCOME_AMT_100000-499999
# 0              False                   False                     False  \
# 1               True                   False                     False
# 2              False                   False                     False
# 3              False                    True                     False
# 4              False                   False                      True
#
#    INCOME_AMT_10M-50M  INCOME_AMT_1M-5M  INCOME_AMT_25000-99999
# 0               False             False                   False  \
# 1               False             False                   False
# 2               False             False                   False
# 3               False             False                   False
# 4               False             False                   False
#
#    INCOME_AMT_50M+  INCOME_AMT_5M-10M  SPECIAL_CONSIDERATIONS_N
# 0            False              False                      True  \
# 1            False              False                      True
# 2            False              False                      True
# 3            False              False                      True
# 4            False              False                      True
#
#    SPECIAL_CONSIDERATIONS_Y
# 0                     False
# 1                     False
# 2                     False
# 3                     False
# 4                     False
#
# [5 rows x 44 columns]

# %%
# Split our preprocessed data into our features and target arrays
X = app_dummies.drop(["IS_SUCCESSFUL"], axis=1).values
y = app_dummies["IS_SUCCESSFUL"].values

# Split the preprocessed data into a training and testing dataset
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=78)

# %%
# Create a StandardScaler instances
scaler = StandardScaler()

# Fit the StandardScaler
X_scaler = scaler.fit(X_train)

# Scale the data
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %%
X_train_scaled.shape
inputs = X_train_scaled.shape[1]

# %%
# Create a method that creates a new Sequential model with hyperparameter options
def create_model(hp):
    nn_model = tf.keras.models.Sequential()

    # Allow kerastuner to decide which activation function to use in hidden layers
    activation = hp.Choice('activation',['relu','tanh','sigmoid'])
    
    # Allow kerastuner to decide number of neurons in first layer
    nn_model.add(tf.keras.layers.Dense(units=hp.Int('first_units',
        min_value=1,
        max_value=10,
        step=2), activation=activation, input_dim=inputs))

    # Allow kerastuner to decide number of hidden layers and neurons in hidden layers
    for i in range(hp.Int('num_layers', 1, 6)):
        nn_model.add(tf.keras.layers.Dense(units=hp.Int('units_' + str(i),
            min_value=1,
            max_value=30,
            step=2),
            activation=activation))
    
    nn_model.add(tf.keras.layers.Dense(units=1, activation="sigmoid"))

    # Compile the model
    nn_model.compile(loss="binary_crossentropy", optimizer='adam', metrics=["accuracy"])
    
    return nn_model

# %%
tuner = kt.Hyperband(
    create_model,
    objective="val_accuracy",
    max_epochs=50,
    hyperband_iterations=3)

# %%
# Run the kerastuner search for best hyperparameters NOTE: THIS WILL TAKE A LONG TIME TO RUN!!
tuner.search(X_train_scaled,y_train,epochs=50,validation_data=(X_test_scaled,y_test))
# Out:
# Trial 270 Complete [00h 00m 54s]
# val_accuracy: 0.7276967763900757
#
# Best val_accuracy So Far: 0.7306122183799744
# Total elapsed time: 01h 02m 37s
# INFO:tensorflow:Oracle triggered exit

# %%
# Get best model hyperparameters
best_hyper = tuner.get_best_hyperparameters(1)[0]
best_hyper.values
# Out:
# {'activation': 'relu',
#  'first_units': 9,
#  'num_layers': 6,
#  'units_0': 15,
#  'units_1': 15,
#  'units_2': 17,
#  'units_3': 19,
#  'units_4': 13,
#  'units_5': 13,
#  'tuner/epochs': 50,
#  'tuner/initial_epoch': 0,
#  'tuner/bracket': 0,
#  'tuner/round': 0}

# %%
# Evaluate best model against full test data
best_model = tuner.get_best_models()[0]
model_loss, model_accuracy = best_model.evaluate(X_test_scaled,y_test,verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# WARNING:tensorflow:Detecting that an object or model or tf.train.Checkpoint is being deleted with unrestored values. See the following logs for the specific values in question. To silence these warnings, use `status.expect_partial()`. See https://www.tensorflow.org/api_docs/python/tf/train/Checkpoint#restorefor details about the status object returned by the restore function.
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.1
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.2
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.3
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.4
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.5
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.6
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.7
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.8
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.9
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.10
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.11
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.12
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.13
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.14
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.15
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.16
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.17
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.18
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.19
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.20
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.21
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.22
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.23
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.24
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.25
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.26
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.27
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.28
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.29
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.30
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.31
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.32
# 268/268 - 0s - loss: 0.5512 - accuracy: 0.7306 - 297ms/epoch - 1ms/step
# Loss: 0.5512012839317322, Accuracy: 0.7306122183799744

# %%
# Define the model - deep neural net, i.e., the number of input features and hidden nodes for each layer.
inputs = len(X_test_scaled[0])

nn = tf.keras.models.Sequential()

# Add specified number of hidden layers with specified number of neurons per layer
for i in range(best_hyper.values['num_layers']):
    nn.add(tf.keras.layers.Dense(units=best_hyper.values['units_' + str(i)],
        activation=best_hyper.values['activation']))
    
# Add output layer with sigmoid activation function
nn.add(tf.keras.layers.Dense(units=1, activation="sigmoid"))

# Compile the model
nn.compile(loss="binary_crossentropy", optimizer='adam', metrics=["accuracy"])

# Train the model
fit_model = nn.fit(X_train_scaled,y_train,epochs=150)
# Out:
# Epoch 1/150
# 804/804 [==============================] - 2s 1ms/step - loss: 0.5861 - accuracy: 0.7031
# Epoch 2/150
# 804/804 [==============================] - 1s 959us/step - loss: 0.5564 - accuracy: 0.7295
# Epoch 3/150
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5531 - accuracy: 0.7303
# Epoch 4/150
# 804/804 [==============================] - 1s 990us/step - loss: 0.5521 - accuracy: 0.7312
# Epoch 5/150
# 804/804 [==============================] - 1s 983us/step - loss: 0.5502 - accuracy: 0.7327
# Epoch 6/150
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5504 - accuracy: 0.7311
# Epoch 7/150
# 804/804 [==============================] - 1s 991us/step - loss: 0.5494 - accuracy: 0.7321
# Epoch 8/150
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5485 - accuracy: 0.7338
# Epoch 9/150
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5480 - accuracy: 0.7344
# Epoch 10/150
# 804/804 [==============================] - 1s 981us/step - loss: 0.5476 - accuracy: 0.7350
# Epoch 11/150
# 804/804 [==============================] - 1s 956us/step - loss: 0.5472 - accuracy: 0.7342
# Epoch 12/150
# 804/804 [==============================] - 1s 976us/step - loss: 0.5471 - accuracy: 0.7342
# Epoch 13/150
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5467 - accuracy: 0.7343
# Epoch 14/150
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5455 - accuracy: 0.7348
# Epoch 15/150
# 804/804 [==============================] - 1s 958us/step - loss: 0.5458 - accuracy: 0.7353
# Epoch 16/150
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5451 - accuracy: 0.7361
# Epoch 17/150
# 804/804 [==============================] - 1s 969us/step - loss: 0.5452 - accuracy: 0.7357
# Epoch 18/150
# 804/804 [==============================] - 1s 985us/step - loss: 0.5452 - accuracy: 0.7348
# Epoch 19/150
# 804/804 [==============================] - 1s 958us/step - loss: 0.5445 - accuracy: 0.7346
# Epoch 20/150
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5449 - accuracy: 0.7352
# Epoch 21/150
# 804/804 [==============================] - 1s 958us/step - loss: 0.5448 - accuracy: 0.7361
# Epoch 22/150
# 804/804 [==============================] - 1s 982us/step - loss: 0.5440 - accuracy: 0.7367
# Epoch 23/150
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5435 - accuracy: 0.7357
# Epoch 24/150
# 804/804 [==============================] - 1s 967us/step - loss: 0.5437 - accuracy: 0.7362
# Epoch 25/150
# 804/804 [==============================] - 1s 955us/step - loss: 0.5431 - accuracy: 0.7372
# Epoch 26/150
# 804/804 [==============================] - 1s 986us/step - loss: 0.5436 - accuracy: 0.7360
# Epoch 27/150
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5432 - accuracy: 0.7369
# Epoch 28/150
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5430 - accuracy: 0.7368
# Epoch 29/150
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5428 - accuracy: 0.7367
# Epoch 30/150
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5429 - accuracy: 0.7363
# Epoch 31/150
# 804/804 [==============================] - 1s 956us/step - loss: 0.5428 - accuracy: 0.7364
# Epoch 32/150
# 804/804 [==============================] - 1s 999us/step - loss: 0.5428 - accuracy: 0.7374
# Epoch 33/150
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5421 - accuracy: 0.7374
# Epoch 34/150
# 804/804 [==============================] - 1s 946us/step - loss: 0.5423 - accuracy: 0.7379
# Epoch 35/150
# 804/804 [==============================] - 1s 1000us/step - loss: 0.5417 - accuracy: 0.7369
# Epoch 36/150
# 804/804 [==============================] - 1s 971us/step - loss: 0.5422 - accuracy: 0.7380
# Epoch 37/150
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5421 - accuracy: 0.7378
# Epoch 38/150
# 804/804 [==============================] - 1s 1000us/step - loss: 0.5416 - accuracy: 0.7376
# Epoch 39/150
# 804/804 [==============================] - 1s 943us/step - loss: 0.5422 - accuracy: 0.7372
# Epoch 40/150
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5417 - accuracy: 0.7379
# Epoch 41/150
# 804/804 [==============================] - 1s 997us/step - loss: 0.5417 - accuracy: 0.7381
# Epoch 42/150
# 804/804 [==============================] - 1s 968us/step - loss: 0.5411 - accuracy: 0.7384
# Epoch 43/150
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5410 - accuracy: 0.7389
# Epoch 44/150
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5412 - accuracy: 0.7379
# Epoch 45/150
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5407 - accuracy: 0.7378
# Epoch 46/150
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5412 - accuracy: 0.7375
# Epoch 47/150
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5409 - accuracy: 0.7374
# Epoch 48/150
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5404 - accuracy: 0.7389
# Epoch 49/150
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5406 - accuracy: 0.7387
# Epoch 50/150
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5407 - accuracy: 0.7384
# Epoch 51/150
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5405 - accuracy: 0.7385
# Epoch 52/150
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5409 - accuracy: 0.7389
# Epoch 53/150
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5401 - accuracy: 0.7386
# Epoch 54/150
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5401 - accuracy: 0.7385
# Epoch 55/150
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5402 - accuracy: 0.7383
# Epoch 56/150
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5401 - accuracy: 0.7380
# Epoch 57/150
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5399 - accuracy: 0.7392
# Epoch 58/150
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5401 - accuracy: 0.7390
# Epoch 59/150
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5400 - accuracy: 0.7381
# Epoch 60/150
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5393 - accuracy: 0.7383
# Epoch 61/150
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5397 - accuracy: 0.7393
# Epoch 62/150
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5403 - accuracy: 0.7388
# Epoch 63/150
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5398 - accuracy: 0.7390
# Epoch 64/150
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5392 - accuracy: 0.7395
# Epoch 65/150
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5398 - accuracy: 0.7397
# Epoch 66/150
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5391 - accuracy: 0.7389
# Epoch 67/150
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5391 - accuracy: 0.7388
# Epoch 68/150
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5397 - accuracy: 0.7395
# Epoch 69/150
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5390 - accuracy: 0.7396
# Epoch 70/150
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5397 - accuracy: 0.7387
# Epoch 71/150
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5391 - accuracy: 0.7389
# Epoch 72/150
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5394 - accuracy: 0.7391
# Epoch 73/150
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5389 - accuracy: 0.7398
# Epoch 74/150
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5388 - accuracy: 0.7390
# Epoch 75/150
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5391 - accuracy: 0.7393
# Epoch 76/150
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5389 - accuracy: 0.7391
# Epoch 77/150
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5388 - accuracy: 0.7399
# Epoch 78/150
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5387 - accuracy: 0.7398
# Epoch 79/150
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5388 - accuracy: 0.7385
# Epoch 80/150
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5385 - accuracy: 0.7391
# Epoch 81/150
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5389 - accuracy: 0.7390
# Epoch 82/150
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5390 - accuracy: 0.7390
# Epoch 83/150
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5384 - accuracy: 0.7402
# Epoch 84/150
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5383 - accuracy: 0.7393
# Epoch 85/150
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5387 - accuracy: 0.7396
# Epoch 86/150
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5385 - accuracy: 0.7391
# Epoch 87/150
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5389 - accuracy: 0.7389
# Epoch 88/150
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5390 - accuracy: 0.7394
# Epoch 89/150
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5387 - accuracy: 0.7396
# Epoch 90/150
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5383 - accuracy: 0.7397
# Epoch 91/150
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5385 - accuracy: 0.7397
# Epoch 92/150
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5391 - accuracy: 0.7394
# Epoch 93/150
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5380 - accuracy: 0.7399
# Epoch 94/150
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5383 - accuracy: 0.7399
# Epoch 95/150
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5379 - accuracy: 0.7406
# Epoch 96/150
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5382 - accuracy: 0.7401
# Epoch 97/150
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5388 - accuracy: 0.7394
# Epoch 98/150
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5378 - accuracy: 0.7396
# Epoch 99/150
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5381 - accuracy: 0.7399
# Epoch 100/150
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5374 - accuracy: 0.7391
# Epoch 101/150
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5375 - accuracy: 0.7397
# Epoch 102/150
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5380 - accuracy: 0.7390
# Epoch 103/150
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5379 - accuracy: 0.7397
# Epoch 104/150
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5393 - accuracy: 0.7388
# Epoch 105/150
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5383 - accuracy: 0.7392
# Epoch 106/150
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5378 - accuracy: 0.7396
# Epoch 107/150
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5381 - accuracy: 0.7397
# Epoch 108/150
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5380 - accuracy: 0.7394
# Epoch 109/150
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5373 - accuracy: 0.7398
# Epoch 110/150
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5381 - accuracy: 0.7399
# Epoch 111/150
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5382 - accuracy: 0.7390
# Epoch 112/150
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5382 - accuracy: 0.7397
# Epoch 113/150
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5376 - accuracy: 0.7396
# Epoch 114/150
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5380 - accuracy: 0.7397
# Epoch 115/150
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5373 - accuracy: 0.7409
# Epoch 116/150
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5377 - accuracy: 0.7402
# Epoch 117/150
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5373 - accuracy: 0.7400
# Epoch 118/150
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5379 - accuracy: 0.7396
# Epoch 119/150
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5374 - accuracy: 0.7403
# Epoch 120/150
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5377 - accuracy: 0.7400
# Epoch 121/150
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5375 - accuracy: 0.7401
# Epoch 122/150
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5373 - accuracy: 0.7401
# Epoch 123/150
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5375 - accuracy: 0.7402
# Epoch 124/150
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5379 - accuracy: 0.7392
# Epoch 125/150
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5370 - accuracy: 0.7397
# Epoch 126/150
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5379 - accuracy: 0.7407
# Epoch 127/150
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5377 - accuracy: 0.7403
# Epoch 128/150
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5384 - accuracy: 0.7392
# Epoch 129/150
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5380 - accuracy: 0.7394
# Epoch 130/150
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5373 - accuracy: 0.7392
# Epoch 131/150
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5377 - accuracy: 0.7394
# Epoch 132/150
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5375 - accuracy: 0.7392
# Epoch 133/150
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5369 - accuracy: 0.7400
# Epoch 134/150
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5375 - accuracy: 0.7391
# Epoch 135/150
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5368 - accuracy: 0.7398
# Epoch 136/150
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5372 - accuracy: 0.7400
# Epoch 137/150
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5372 - accuracy: 0.7394
# Epoch 138/150
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5372 - accuracy: 0.7391
# Epoch 139/150
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5373 - accuracy: 0.7404
# Epoch 140/150
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5372 - accuracy: 0.7403
# Epoch 141/150
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5373 - accuracy: 0.7401
# Epoch 142/150
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5368 - accuracy: 0.7402
# Epoch 143/150
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5369 - accuracy: 0.7406
# Epoch 144/150
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5375 - accuracy: 0.7402
# Epoch 145/150
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5370 - accuracy: 0.7400
# Epoch 146/150
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5371 - accuracy: 0.7402
# Epoch 147/150
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5366 - accuracy: 0.7404
# Epoch 148/150
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5368 - accuracy: 0.7404
# Epoch 149/150
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5368 - accuracy: 0.7397
# Epoch 150/150
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5377 - accuracy: 0.7401

# %%
# Evaluate the model using the test data
model_loss, model_accuracy = nn.evaluate(X_test_scaled,y_test,verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 268/268 - 0s - loss: 0.5546 - accuracy: 0.7273 - 260ms/epoch - 972us/step
# Loss: 0.5546042323112488, Accuracy: 0.7273469567298889

# %%
loss_df = pd.DataFrame(fit_model.history, index=range(1,len(fit_model.history["loss"])+1))
Attempt3 = loss_df.plot(y="accuracy")

# %%
plt.savefig("Images/Attempt3.png")

# %%
nn.save("h5_Files/AlphabetSoupCharity_Optimization1.h5")
# Out:
# c:\Users\Rstev\anaconda3\lib\site-packages\keras\src\engine\training.py:3000: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
